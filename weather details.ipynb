# %%
import pandas as pd

data=pd.read_csv(r'/content/seattle-weather.csv')

# %%
data
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1461, step=1)

# %%
data.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
data.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %%
data.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %% [markdown]
# find wind speed unique

# %%
data.nunique()
# Out:
# date             1461
# precipitation     111
# temp_max           67
# temp_min           55
# wind               79
# weather             5
# dtype: int64

# %%
data['wind'].nunique()
# Out:
# 79

# %%
data['wind'].unique()
# Out:
# array([4.7, 4.5, 2.3, 6.1, 2.2, 2. , 3.4, 5.1, 1.9, 1.3, 5.3, 3.2, 5. ,
#        5.6, 1.6, 8.2, 4.8, 3.6, 5.4, 1.4, 3.9, 2.7, 2.6, 4.3, 2.9, 2.4,
#        3. , 3.1, 1.8, 2.1, 8.1, 7.5, 5.9, 3.5, 6.4, 4.2, 7. , 6.2, 2.5,
#        2.8, 5.8, 3.8, 5.2, 4.4, 6.8, 4.1, 4. , 8. , 4.6, 1.5, 6.3, 3.3,
#        3.7, 1.7, 6. , 1.1, 7.3, 6.5, 5.7, 5.5, 4.9, 1. , 1.2, 9.5, 0.6,
#        7.1, 7.6, 0.9, 0.4, 7.9, 7.2, 0.5, 0.7, 8.8, 0.8, 6.6, 6.9, 6.7,
#        7.7])

# %% [markdown]
# find the number of item when weather is sunny

# %%
data[data.weather == 'sun']
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 7     2012-01-08            0.0      10.0       2.8   2.0     sun
# 10    2012-01-11            0.0       6.1      -1.1   5.1     sun
# 11    2012-01-12            0.0       6.1      -1.7   1.9     sun
# 12    2012-01-13            0.0       5.0      -2.8   1.3     sun
# 32    2012-02-02            0.0       8.3       1.7   2.6     sun
# ...          ...            ...       ...       ...   ...     ...
# 1427  2015-11-28            0.0       7.2      -2.7   1.0     sun
# 1443  2015-12-14            0.0       7.8       1.7   1.7     sun
# 1455  2015-12-26            0.0       4.4       0.0   2.5     sun
# 1459  2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5     sun
#
# [640 rows x 6 columns]

# %%
data.weather.value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64

# %% [markdown]
# wind speed exactly 3.5

# %%
data[data.wind == 3.5]
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 54    2012-02-24           11.4       6.7       4.4   3.5     rain
# 113   2012-04-23            0.0      21.7       8.9   3.5      sun
# 136   2012-05-16            0.0      19.4       9.4   3.5      sun
# 158   2012-06-07           16.5      16.1       8.9   3.5     rain
# 310   2012-11-06            0.3      12.8       6.7   3.5     rain
# 356   2012-12-22            3.3       8.3       3.9   3.5     rain
# 701   2013-12-02            4.6       7.8       1.7   3.5     rain
# 912   2014-07-01            0.0      34.4      15.6   3.5      sun
# 919   2014-07-08            0.0      30.0      15.6   3.5      sun
# 1002  2014-09-29            0.8      16.7      11.1   3.5     rain
# 1014  2014-10-11            7.4      18.3      11.7   3.5     rain
# 1078  2014-12-14            0.0      12.8       1.7   3.5      fog
# 1191  2015-04-06            1.0      13.9       6.7   3.5     rain
# ...

# %% [markdown]
# weather is exactly sunny and wind above 4.5

# %%
data[(data['weather']=='sun') & (data['wind']>4.5)]
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 10    2012-01-11            0.0       6.1      -1.1   5.1     sun
# 33    2012-02-03            0.0      14.4       2.2   5.3     sun
# 36    2012-02-06            0.0      16.1       1.7   5.0     sun
# 49    2012-02-19            0.0       6.7       2.2   4.7     sun
# 62    2012-03-03            0.0      12.2       6.7   7.0     sun
# 83    2012-03-24            0.0      15.0       3.3   5.2     sun
# 168   2012-06-17            0.0      18.9      11.7   6.4     sun
# 227   2012-08-15            0.0      31.1      16.7   4.7     sun
# 255   2012-09-12            0.0      22.2      10.0   5.6     sun
# 276   2012-10-03            0.0      18.9       7.8   7.3     sun
# 277   2012-10-04            0.0      18.9       8.3   6.5     sun
# 278   2012-10-05            0.0      21.7       8.9   5.7     sun
# 279   2012-10-06            0.0      23.9       7.8   5.1     sun
# ...
